# %% [markdown]
# # Лабораторная работа №1: Исследование двумерного нормального распределения
# Выполнил студент гр. 1384 Овчинников Максим. Вариант №11

# %% [markdown]
# ## Цель работы
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
# Случайный вектор $\overrightarrow{\xi} = \left(\xi_1, \dots, \xi_n\right)^\intercal:\Omega\to \mathbb{R}^n$ имеет многомерное нормальное распределение, если существует вектор независимых стандартных нормальных случайных величин $\overrightarrow{\eta} = \left(\eta_1, \dots, \eta_m\right)^\intercal$, матрица $A$ размерности $n \times m$ и вещественный вектор $\overrightarrow{b} = (b_1,\dots,b_n)^\intercal$, такие что: $\overrightarrow{\xi} = A\overrightarrow{\eta} + \overrightarrow{b}$.
#
# Плотность многомерного невырожденного нормального распределения имеет вид: $\mathcal{p}_{\overrightarrow{\xi}}\left(x_1, \dots, x_n\right) = \frac{1}{(2\pi)^{n/2}\sqrt{\det \Sigma}} \exp\left(-\frac{1}{2}\left(\overrightarrow{x}-\overrightarrow{\mu}\right)^\intercal \Sigma^{-1}\left(\overrightarrow{x}-\overrightarrow{\mu}\right)\right)$,
# где $\overrightarrow{\mu} = \mathbb{E}\overrightarrow{\xi} = \left(\mathbb{E}\xi_1, \dots, \mathbb{E}\xi_n\right)^\intercal$ - вектор математических ожиданий компонент,
# $\Sigma = \left\{\sigma_{i,j}\right\}_{i,j=1}^n$ - ковариационная матрица, $\sigma_{i,j} = \mathop{\mathrm{cov}}\left(\xi_i,\xi_j\right)$
#
# Свойства многомерного нормального распределения:
# - Линейная комбинация случайных переменных, принадлежащих многомерному нормальному распределению, также является нормально распределенной
# - Условные и безусловные распределения, полученные из многомерного нормального распределения, также являются нормально распределенными.
# - Параметры многомерного нормального распределения (средние и ковариационная матрица) полностью описывают его форму
# - Многомерное нормальное распределение устойчиво относительно линейных преобразований. Если $\overrightarrow{\xi} \sim \mathcal{N}\left(\overrightarrow{\mu}, \Sigma\right)$, $A$ - произвольная матрица размерности $m \times n$, a $\overrightarrow{b}$ - произвольный вектор размерности $m \times 1$, то $A\overrightarrow{\xi}+\overrightarrow{b} \sim \mathcal{N}\left(A\overrightarrow{\mu}+\overrightarrow{b}, A \Sigma A^\intercal\right)$

# %% [markdown]
# ## Постановка задачи
# Плотность двумерного нормального распределения имеет вид: $p_{\xi,\eta}(x,y) = C \cdot exp \left(-\frac{1}{2} (2x^{2}+4xy+5y^{2}-8x-2y+11)\right)$
#
# 1. Вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора. Построить график плотности распределения $p_{\xi,\eta}$.
# 2. Найти аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный.
# 3. Найти ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами. Построить график плотности полученного распределения.
# 4. Вычислить характеристики совместного распределения случайного вектора $(-3\xi -3\eta,-2\xi -4\eta)^{\intercal}$ и записать его плотность. Построить график плотности полученного распределения.
# 5. Найти условное распределение $\xi$ при условии $\eta$. Вычислить $\mathbb{E}(\xi|\eta)$ и $\mathbb{D}(\xi|\eta)$.

# %% [markdown]
# ## Выполнение работы
#
# ### 1. Вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора. Построить график плотности распределения $p_{\xi,\eta}$.
#
# Преобразуем выражение $q(x,y) = 2x^{2} + 4xy + 5y^{2} - 8x - 2y + 11$:
#
# $\begin{split}
# q(x,y) &= 2x^{2} + 4xy + 5y^{2} - 8x - 2y + 11 = \\
# &= \left(2x^{2} + 4x(y-2)\right) + 5y^{2} - 2y + 11 = \\
# &= 2\left(x^{2} + 2x(y-2) + (y-2)^{2}\right) + \left(5y^{2} - 2y + 11 - 2(y-2)^{2}\right) = \\
# &= 2\left(x + (y-2)\right)^{2} + \left(5y^{2} - 2y + 11 - 2(y^{2} - 4y + 4)\right) = \\
# &= 2\left(x + (y-2)\right)^{2} + (3y^{2} + 6y + 3) = \\
# &= 2\left(x + (y+1) - 3\right)^{2} + 3(y+1)^{2} = \\
# &= 2(x-3)^{2} + 4(x-3)(y+1) + 2(y+1)^{2} + 3(y+1)^{2} = \\
# &= 2(x-3)^{2} + 4(x-3)(y+1) + 5(y+1)^{2}
# \end{split}$
#
# Найдем вектор математических ожиданий:
#
# $
# \mathbb{E}
#     \begin{pmatrix}
#         \xi \\ \eta
#     \end{pmatrix} =
#     \begin{pmatrix}
#         3 \\ -1
#     \end{pmatrix}
# $
#
# Найдем обратную ковариационную матрицу:
#
# $\Sigma^{-1} =
#     \begin{pmatrix}
#         2 & 2 \\
#         2 & 5
#     \end{pmatrix}$
#
#
# $\det{\Sigma^{-1}} = 6$
#
# Ковариационная матрица и числовые характеристики:
#
# $
# \Sigma = \frac{1}{6} \cdot
#     \begin{pmatrix}
#         5 & -2 \\
#         -2 & 2
#     \end{pmatrix}
# $
#
# $\mathbb{D}\xi = \frac{5}{6}$
#
# $\mathbb{D}\eta = \frac{1}{3}$
#
# $\mathop{\mathrm{cov}}\nolimits(\xi, \eta) = -\frac{1}{3}$
#
# $\rho(\xi, \eta) = - \frac{1}{3} \cdot \frac{1}{\sqrt{\frac{5}{6} \cdot \frac{1}{3}}} = -\frac{2}{\sqrt{10}}$
#
# Найдем константу:
#
# $C = \frac{\sqrt{6}}{2\pi}$
#
# Функция плотности распределения:
#
# $p_{\xi,\eta}(x,y) = \frac{\sqrt{6}}{2\pi} \cdot exp \left(-\frac{1}{2}
#     \left[\begin{pmatrix}
#         x \\ y
#     \end{pmatrix}
#     -
#     \begin{pmatrix}
#         3 \\ -1
#     \end{pmatrix}\right
#     ]^{\intercal}
#     \begin{pmatrix}
#         2 & 2 \\
#         2 & 5
#     \end{pmatrix}
#     \left[\begin{pmatrix}
#         x \\ y
#     \end{pmatrix}
#     -
#     \begin{pmatrix}
#         3 \\ -1
#     \end{pmatrix}\right]
#     \right)
# $

# %% [markdown]
# Построим график плотности распределения $p_{\xi,\eta}$

# %%
import numpy as np
import matplotlib.pyplot as plt


def graph(x,y,p):

    fig = plt.figure()
    ax = fig.add_subplot(111,projection='3d')
    
    ax.plot_surface(x,y,p,cmap='plasma');
    ax.set_title('График плотности')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('p')
    
    plt.show()

def pdf(x,y):
    return ( (np.sqrt(6) / 2 * np.pi) * np.exp(-0.5 * (2*x**2 -8*x + 11 + 4*x*y - 2*y + 5*y*y)) )

x = np.linspace(start=0, stop=6, num=100)
y = np.linspace(start=-5, stop=3, num=100)
X, Y = np.meshgrid(x,y)
p = pdf(X,Y)


graph(X,Y,p)

# %% [markdown]
# ### 2.Найти аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный.
#
# Вернемся к $q(x,y)$ из задания 1:
#
# $
# q(x,y) = 2\left(x + (y-2)\right)^{2} + 3(y+1)^{2} = \left(\frac{2}{\sqrt{2}}x + \frac{2}{\sqrt{2}}y - \frac{4}{\sqrt{2}}\right)^{2} + \left(\frac{3}{\sqrt{3}}y + \frac{3}{\sqrt{3}}\right)^{2}
# $
#
# Получим аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный:
#
# $
# \begin{pmatrix}
#     \xi_{st} \\ \eta_{st}
# \end{pmatrix} =
# \begin{pmatrix}
#     \frac{2}{\sqrt{2}} & \frac{2}{\sqrt{2}} \\
#     0 & \frac{3}{\sqrt{3}}
# \end{pmatrix}
# \begin{pmatrix}
#     \xi \\ \eta
# \end{pmatrix} +
# \begin{pmatrix}
#     -\frac{4}{\sqrt{2}} \\ \frac{3}{\sqrt{3}}
# \end{pmatrix}
# $
#
#
# Выполним проверку. Найдем вектор математических ожиданий и ковариационную матрицу:
#
# $
# \mathbb{E}\begin{pmatrix}
#     \xi_{st} \\ \eta_{st}
# \end{pmatrix} =
# \begin{pmatrix}
#     \frac{2}{\sqrt{2}} & \frac{2}{\sqrt{2}} \\
#     0 & \frac{3}{\sqrt{3}}
# \end{pmatrix}
# \begin{pmatrix}
#     3 \\ -1
# \end{pmatrix} +
# \begin{pmatrix}
#     -\frac{4}{\sqrt{2}} \\ \frac{3}{\sqrt{3}}
# \end{pmatrix} =
# \begin{pmatrix}
#     0 \\ 0
# \end{pmatrix}
# $
#
# $
# \Sigma_{st} = \frac{1}{6}
# \begin{pmatrix}
#     \frac{2}{\sqrt{2}} & \frac{2}{\sqrt{2}} \\
#     0 & \frac{3}{\sqrt{3}}
# \end{pmatrix}
# \begin{pmatrix}
#     5 & -2 \\
#     -2 & 2
# \end{pmatrix}
# \begin{pmatrix}
#     \frac{2}{\sqrt{2}} & 0 \\
#     \frac{2}{\sqrt{2}} & \frac{3}{\sqrt{3}}
# \end{pmatrix} =
# \begin{pmatrix}
#     1 & 0 \\
#     0 & 1
# \end{pmatrix}
# $

# %% [markdown]
# ### 3. Найти ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами. Построить график плотности полученного распределения.
#
# $\Sigma^{-1} =
#     \begin{pmatrix}
#         2 & 2 \\
#         2 & 5
#     \end{pmatrix}$
#
# Найдем собственные числа:
#
# $
# \begin{vmatrix}
#     2 - \lambda & 2 \\
#     2 & 5 - \lambda
# \end{vmatrix} = 0
# $
#
# $
# \lambda^{2} - 7\lambda + 6 = 0
# $
#
#
# $\lambda_{1} = 1,$ $\lambda_{2} = 6$
#
#
# Найдем нормированные собственные вектора:
#
# Для $\lambda_{1} = 1$:
#
# $
# \begin{pmatrix}
#     1 & 2 \\
#     2 & 4
# \end{pmatrix}
# \begin{pmatrix}
#     v_{1x} \\ v_{1y}
# \end{pmatrix} =
# \begin{pmatrix}
#     0 \\ 0
# \end{pmatrix}
# $
#
# $
# v_{1} =
# \begin{pmatrix}
#     2 \\ -1
# \end{pmatrix} *
# \frac{1}{\sqrt{5}}
# $
#
# Для $\lambda_{1} = 6$:
#
# $
# \begin{pmatrix}
#     -4 & 2 \\
#     2 & -1
# \end{pmatrix}
# \begin{pmatrix}
#     v_{2x} \\ v_{2y}
# \end{pmatrix} =
# \begin{pmatrix}
#     0 \\ 0
# \end{pmatrix}
# $
#
# $
# v_{2} =
# \begin{pmatrix}
#     1 \\ 2
# \end{pmatrix} *
# \frac{1}{\sqrt{5}}
# $
#
# Объеденим полученные векторы и получим транспонированную матрицу ортогонального преобразования:
#
# $
# Q^{\intercal} = \frac{1}{\sqrt{5}}
# \begin{pmatrix}
#     2 & 1 \\
#     -1 & 2
# \end{pmatrix}
# $
#
# $
# Q = \frac{1}{\sqrt{5}}
# \begin{pmatrix}
#     2 & -1 \\
#     1 & 2
# \end{pmatrix}
# $
#
# $
# \begin{pmatrix}
#     \xi_{ort} \\ \eta_{ort}
# \end{pmatrix} =
# Q
# \begin{pmatrix}
#     \xi \\ \eta
# \end{pmatrix} =
# \frac{1}{\sqrt{5}}
# \begin{pmatrix}
#     2\xi  -\eta \\
#     \xi  + 2\eta
# \end{pmatrix}
# $
#
# Найдем вектор математических ожиданий:
#
# $\mathbb{E}
# \begin{pmatrix}
#     \xi_{ort} \\ \eta_{ort}
# \end{pmatrix} =
# \frac{1}{\sqrt{5}}
# \begin{pmatrix}
#     6 + 1 \\
#     3 - 2
# \end{pmatrix} =
# \frac{1}{\sqrt{5}}
# \begin{pmatrix}
#     7 \\ 1
# \end{pmatrix}
# $
#
# Найдем ковариационную матрицу:
#
# $\Sigma_{ort} =
# \frac{1}{30}
# \begin{pmatrix}
#     2 & -1 \\
#     1 & 2
# \end{pmatrix}
# \begin{pmatrix}
#     5 & -2 \\
#     -2 & 2
# \end{pmatrix}
# \begin{pmatrix}
#     2 & 1 \\
#     -1 & 2
# \end{pmatrix}=
# \begin{pmatrix}
#     1 & 0 \\
#     0 & \frac{1}{6}
# \end{pmatrix}
# $
#
# $
# \Sigma_{ort}^{-1} =
# \begin{pmatrix}
#     1 & 0 \\
#     0 & 6
# \end{pmatrix}
# $
#
# Найдем константу:
#
# $
# C = \frac{1}{2\pi\sqrt{1 + \frac{1}{6}}} = \frac{\sqrt{42}}{14\pi}
# $
#
# Функция плотности распределения:
#
# $p_{\xi,\eta}(x,y) = \frac{\sqrt{42}}{14\pi} \cdot exp \left(-\frac{1}{2}
#     \left[\begin{pmatrix}
#         x \\ y
#     \end{pmatrix}
#     -
#     \begin{pmatrix}
#         \frac{7}{\sqrt{5}} \\ \frac{1}{\sqrt{5}}
#     \end{pmatrix}\right
#     ]^{\intercal}
#     \begin{pmatrix}
#         1 & 0 \\
#         0 & 6
#     \end{pmatrix}
#     \left[\begin{pmatrix}
#         x \\ y
#     \end{pmatrix}
#     -
#     \begin{pmatrix}
#         \frac{7}{\sqrt{5}} \\ \frac{1}{\sqrt{5}}
#     \end{pmatrix}\right]
#     \right)
# $

# %% [markdown]
# Построим график плотности распределения $p_{\xi_{ort},\eta_{ort}}$

# %%
def pdf(x,y):
    return ( (np.sqrt(42) / 14 * np.pi) * np.exp(-0.5 * (x**2 -((14*np.sqrt(5))/5)*x + 11 - ((12*np.sqrt(5))/5)*y + 6*y*y)) )

x = np.linspace(start=0, stop=7, num=100)
y = np.linspace(start=-2, stop=3, num=100)
X, Y = np.meshgrid(x,y)
p = pdf(X,Y)


graph(X,Y,p)

# %% [markdown]
# ### 4. Вычислить характеристики совместного распределения случайного вектора $(-3\xi -3\eta,-2\xi -4\eta)^{\intercal}$ и записать его плотность. Построить график плотности полученного распределения.
#
# $
# \begin{pmatrix}
#     \xi_{4} \\ \eta_{4}
# \end{pmatrix} =
# \begin{pmatrix}
#     -3\xi & -3\eta \\
#     -2\xi & -4\eta
# \end{pmatrix} =
# \begin{pmatrix}
#     -3 & -3 \\
#     -2 & -4
# \end{pmatrix}
# \begin{pmatrix}
#     \xi \\ \eta
# \end{pmatrix}
# $
#
#
# $
# A=\begin{pmatrix}
#     -3 & -3 \\
#     -2 & -4
# \end{pmatrix}
# $
#
#
# Матрица невырожденная:
#
# $
# \det A = 12 - 6 = 6
# $
#
# Найдем числовые характеристики:
#
# $
# \mathbb{E}
# \begin{pmatrix}
#     \xi_{4} \\ \eta_{4}
# \end{pmatrix} =
# \begin{pmatrix}
#     -3 & -3 \\
#     -2 & -4
# \end{pmatrix}
# \begin{pmatrix}
#     -3 \\ 1
# \end{pmatrix} =
# \begin{pmatrix}
#     -6 \\ -2
# \end{pmatrix}
# $
#
# $
# \Sigma_{4} = \frac{1}{6}
# \begin{pmatrix}
#     -3 & -3 \\
#     -2 & -4
# \end{pmatrix}
# \begin{pmatrix}
#     5 & -2 \\
#     -2 & 2
# \end{pmatrix}
# \begin{pmatrix}
#     -3 & -2 \\
#     -3 & -4
# \end{pmatrix}=
# \frac{1}{6}
# \begin{pmatrix}
#     27 & 18 \\
#     18 & 20
# \end{pmatrix}
# $
#
# $
# \mathbb{D}_{\xi_{4}} = \frac{9}{2}
# $
#
# $
# \mathbb{D}_{\eta_{4}} = \frac{17}{6}
# $
#
# $\mathop{\mathrm{cov}}\nolimits(\xi_{4}, \eta_{4}) = 3$
#
# $\rho(\xi, \eta) = \frac{3}{\sqrt{\frac{9}{2} \cdot \frac{17}{6}}} = \frac{2\sqrt{51}}{17}$
#
# $
# \Sigma^{-1} =
# \begin{pmatrix}
#     \frac{5}{9} & -\frac{1}{2} \\
#     -\frac{1}{2} & \frac{3}{4}
# \end{pmatrix}
# $
#
# Найдем константу:
#
# $
# C = \frac{1}{2\pi\sqrt{6}} = \frac{\sqrt{6}}{12\pi}
# $
#
# Функция плотности распределения:
#
# $p_{\xi,\eta}(x,y) = \frac{\sqrt{6}}{12\pi} \cdot exp \left(-\frac{1}{2}
#     \left[\begin{pmatrix}
#         x \\ y
#     \end{pmatrix}
#     -
#     \begin{pmatrix}
#         -6 \\ -2
#     \end{pmatrix}\right
#     ]^{\intercal}
#     \begin{pmatrix}
#         \frac{5}{9} & -\frac{1}{2} \\
#         -\frac{1}{2} & \frac{3}{4}
#     \end{pmatrix}
#     \left[\begin{pmatrix}
#         x \\ y
#     \end{pmatrix}
#     -
#     \begin{pmatrix}
#          -6 \\ -2
#     \end{pmatrix}\right]
#     \right)
# $

# %% [markdown]
# Построим график плотности распределения $p_{\xi_{4},\eta_{4}}$

# %%
def pdf(x,y):
    return ( (np.sqrt(6) / 12 * np.pi) * np.exp(-0.5 * ((5/9)*x**2 + (14/3)*x + 11 - x*y - 3*y  + (3/4)*y*y)) )

x = np.linspace(start=-15, stop=3, num=100)
y = np.linspace(start=-10, stop=10, num=100)
X, Y = np.meshgrid(x,y)
p = pdf(X,Y)

graph(X,Y,p)

# %% [markdown]
# ### 5. Найти условное распределение $\xi$ при условии $\eta$. Вычислить $\mathbb{E}(\xi|\eta)$ и $\mathbb{D}(\xi|\eta)$.
#
# Из пункта 1:
#
# $\mathbb{E}_{\eta} = -1$
#
# $\mathbb{D}_{\eta} = \frac{1}{3}$
#
# Тогда:
#
# $
# p_{\eta}(y) = \frac{\sqrt{3}}{\sqrt{2\pi}} \cdot \exp(-\frac{1}{2}\cdot(y+1)\cdot3\cdot(y+1)) = \frac{\sqrt{3}}{\sqrt{2\pi}} \cdot \exp(-\frac{3}{2}(y+1)^{2})
# $
#
# Найдем плотность условного распределения:
#
# $\begin{split}
# p_{\xi|\eta=y}(x) &= \frac{p_{\xi,\eta}(x,y)}{p_{\eta}(y)} = \\
# &= \frac{\frac{\sqrt{6}}{2\pi}\cdot\exp\left(-\frac{1}{2}(2x^{2} + 5y^{2} - 8x - 2y + 4xy +11)\right)}{\frac{\sqrt{3}}{\sqrt{2\pi}}\cdot\exp\left(-\frac{1}{2}(3y^{2} + 6y + 3)\right)} = \\
# &= \frac{1}{\sqrt{\pi}} \cdot \exp\left(-\frac{1}{2}(2x^2 + 5y^{2} - 3y^{2} - 8x - 2y - 6y + 4xy + 11 -3)\right) = \\
# &= \frac{1}{\sqrt{\pi}} \cdot \exp\left(-\frac{1}{2}(2x^2 + 2y^{2} - 8x - 8y + 4xy + 8)\right) = \\
# &= \frac{1}{\sqrt{\pi}} \cdot \exp\left(-\frac{1}{2}(2x^{2} + 4x(y-2) +2(y-2)^{2}\right) = \\
# &= \frac{1}{\sqrt{\pi}} \cdot \exp\left(-\frac{1}{2}(2x^{2} + 4x(y-2) +2(y-2)^{2}\right) = \\
# &= \frac{1}{\sqrt{\pi}} \cdot \exp\left(-\frac{1}{2}(2(x + (y-2)^{2})\right)
# \end{split}$
#
# Тогда математическое ожидание и дисперсия:
#
# $\mathbb{E}(\xi|\eta = y) = -(y-2)$
#
# $\mathbb{D}(\xi|\eta = y) = \frac{1}{2}$

# %% [markdown]
# ## Выводы
#
# В ходе лабораторной работы были исследованы свойства двумерного случайного вектора имеющего нормальное распределение, приобретены навыки преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.
#
# Вычислен вектор математических ожиданий и ковариационные характеристики данного случайного вектора.
#
# Найдено афинное преобразование, переводящее исходный случайный вектор в стандартный нормальный.
#
# Найдено ортогональное преобразование, переводящее центрированный случайный вектор в вектор с независимыми компонентами.
#
# Вычислены характеристики совместного распределения случайного вектора $(-3\xi -3\eta,-2\xi -4\eta)^{\intercal}$ и записана его плотность.
#
# Найдено условное распределение $\xi$ при условии $\eta$, вычесленно $\mathbb{E}(\xi|\eta)$ и  $\mathbb{D}(\xi|\eta)$.
#
# Были построены графики получившихся плотностей распределения.
