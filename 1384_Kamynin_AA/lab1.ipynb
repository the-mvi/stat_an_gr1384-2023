# %% [markdown]
# # Лабораторная работа №1: Исследование двумерного нормального распределения
# Выполнил студент гр. 1384 Камынин Александр. Вариант №5

# %% [markdown]
# ## Цель работы
# Исследовать свойства двумерного случайного вектора, имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
# Случайный вектор $\overrightarrow{\xi} = \left(\xi_1, \dots, \xi_n\right)^\intercal:\Omega\to \mathbb{R}^n$ имеет многомерное нормальное распределение, если существует вектор независимых стандартных нормальных случайных величин $\overrightarrow{\eta} = \left(\eta_1, \dots, \eta_m\right)^\intercal$, матрица $\mathbf{A}$ размерности $n \times m$ и вещественный вектор $\overrightarrow{b} = (b_1,\dots,b_n)^\intercal$, такие что: $\overrightarrow{\xi} = \mathbf{A}\overrightarrow{\eta} + \overrightarrow{b}$.
#
# Плотность многомерного невырожденного нормального распределения имеет вид: $\mathcal{p}_{\overrightarrow{\xi}}\left(x_1, \dots, x_n\right) = \frac{1}{(2\pi)^{n/2}\sqrt{\det \Sigma}} \exp\left(-\frac{1}{2}\left(\overrightarrow{x}-\overrightarrow{\mu}\right)^\intercal \Sigma^{-1}\left(\overrightarrow{x}-\overrightarrow{\mu}\right)\right)$, где $\overrightarrow{\mu} = \mathbb{E}\overrightarrow{\xi} = \left(\mathbb{E}\xi_1, \dots, \mathbb{E}\xi_n\right)^\intercal$ - вектор математических ожиданий компонент, $\Sigma = \left\{\sigma_{i,j} = \mathop{\mathrm{cov}}\left(\xi_i,\xi_j\right)\right\}_{i,j=1}^n$ - ковариационная матрица.
#
#
# Свойства многомерного нормального распределения:
# - Линейная комбинация случайных переменных, принадлежащих многомерному нормальному распределению, также является нормально распределенной
#
# - Условные и безусловные распределения, полученные из многомерного нормального распределения, также являются нормально распределенными. $\mathcal{p}_{\xi|\eta=y}(x) = \frac{\mathcal{p}_{\xi,\eta}(x,y)}{\mathcal{p}_{\eta}(y)}$
#
# - Параметры многомерного нормального распределения (средние и ковариационная матрица) полностью описывают его форму
#
# - Многомерное нормальное распределение устойчиво относительно линейных преобразований. Если $\overrightarrow{\xi} \sim \mathcal{N}\left(\overrightarrow{\mu}, \Sigma\right)$, $A$ - произвольная матрица размерности $m \times n$, $\overrightarrow{b}$ - произвольный вектор размерности $n \times 1$, то $A\overrightarrow{\xi}+\overrightarrow{b} \sim \mathcal{N}\left(A\overrightarrow{\mu}+\overrightarrow{b}, A \Sigma A^\intercal\right)$.

# %% [markdown]
# ## Постановка задачи
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Выполнение работы
# ### 1. Вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора. Построить график плотности распределения $\mathcal{p}_{\xi,\eta}$

# %% [markdown]
# $\mathcal{p}_{\xi,\eta}(x,y) = C \cdot \exp(-\frac{1}{2} (3x^2 - 3xy + 7y^2 + 9x + 8y + 13))$

# %% [markdown]
# $\begin{split}
#   q(x,y) = 3x^2-3xy+7y^2+9x+8y+13 = \\
#   (3x^2-3xy+9x)+7y^2+8y+13 = \\
#   3(x^2-x(y-3))+7y^2+8y+13 = \\
#   3(x^2-2x(\frac{y}{2}-\frac{3}{2}))+7y^2+8y+13 = \\
#   3(x-\frac{y}{2}+\frac{3}{2})^2-\frac{3}{4}(y-3)^2+7y^2+8y+13 = \\
#   3(x-\frac{y}{2}+\frac{3}{2})^2+\frac{-3y^2+18y-27+28y^2+32y+52}{4} = \\
#   3(x-\frac{y}{2}+\frac{3}{2})^2+\frac{25y^2+50y+25}{4} = \\
#   3(x-\frac{y}{2}+\frac{3}{2})^2+\frac{25}{4}(y+1)^2 = \\
#   3(x+\frac{3-y}{2})^2+\frac{25}{4}(y+1)^2 = \\
#   3(x+\frac{-1-y}{2}+2)^2+\frac{25}{4}(y+1)^2 = \\
#   3(x+2-\frac{1}{2}(y+1))^2+\frac{25}{4}(y+1)^2 = \\
#   3(x+2)^2-3(y+1)(x+2)+7(y+1)^2 \\
# \end{split}$

# %% [markdown]
# $E \begin{pmatrix}\xi \\ \eta \end{pmatrix} = \begin{pmatrix} -2 \\ -1 \end{pmatrix}$
#
# $Σ^{-1} = \begin{pmatrix}3 & -\frac{3}{2} \\ -\frac{3}{2} & 7 \end{pmatrix}$
#
# $Σ = \frac{4}{75} \begin{pmatrix}7 & \frac{3}{2} \\ \frac{3}{2} & 3 \end{pmatrix} $
#
# $D\xi = \frac{28}{75}$
#
# $D\eta = \frac{12}{75}$
#
# $cov(\xi,\eta)=\frac{2}{25}$
#
# $ρ(\xi,\eta)=\frac{cov(\xi,\eta)}{\sqrt {\mathbb{D}\xi \cdot \mathbb{D}\eta} } = \frac{2}{25 ⋅ \sqrt{\frac{28}{75} ⋅ \frac{12}{75}}} = \frac{3}{2 \sqrt{21}}$
#
# $C = \frac{1}{2\pi \cdot \sqrt{\detΣ}} = \frac{5}{4\pi\sqrt{\frac{1}{3}}}$
#
# $p_{\xi,\eta}(x,y) = \frac{5 \sqrt{3}}{4\pi} \cdot \exp[-\frac{1}{2}\begin{pmatrix} x + 2 \\ y + 1 \end{pmatrix}^{t} \cdot \begin{pmatrix}3 & -\frac{3}{2} \\ -\frac{3}{2} & 7 \end{pmatrix} \cdot \begin{pmatrix} x + 2 \\ y + 1 \end{pmatrix}]$

# %%
import numpy as np
import matplotlib.pyplot as plt

def p(x,y):
  return (5 * np.sqrt(3)) / (4 * np.pi) * np.exp(-0.5 * (3*x**2 - 3*x*y + 7*y**2 + 9*x + 8*y + 13))

x = np.linspace(-4, 0, 100)
y = np.linspace(-3, 1, 100)

X, Y = np.meshgrid(x,y)
Z = p(X,Y)

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection="3d")

ax.plot_surface(X, Y, Z, cmap = "plasma")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("Плотность распределения")
plt.show()

# %% [markdown]
# ### 2. Найти афинное преобразование, переводящее исходный случайный вектор в стандартный нормальный

# %% [markdown]
# $ 3(x-\frac{y}{2} + \frac{3}{2})^2 + \frac{25}{4}(y+1)^2 = (\sqrt{3}x - \frac{\sqrt{3}y}{2} + \frac{3\sqrt{3}}{2})^2 + (\frac{5y}{2} + \frac{5}{2})^2$
#
# $\begin{pmatrix}\xi_{st} \\ \eta_{st} \end{pmatrix} = \begin{pmatrix} \sqrt{3} & -\frac{\sqrt{3}}{2} \\ 0 & \frac{5}{2} \end{pmatrix} \begin{pmatrix} \xi \\ \eta \end{pmatrix} + \begin{pmatrix} \frac{3\sqrt{3}}{2} \\ \frac{5}{2} \end{pmatrix}$
#
# Проверка полученных результатов:
#
# $ \mu_{st} = \begin{pmatrix} \sqrt{3} & -\frac{\sqrt{3}}{2} \\ 0 & \frac{5}{2}\end{pmatrix} \begin{pmatrix} -2 \\ -1 \end{pmatrix} + \begin{pmatrix} \frac{3\sqrt{3}}{2} \\ \frac{5}{2} \end{pmatrix} = 0 $
#
# $
# \Sigma_{st} = A \Sigma A^{t} = \frac{4}{75} \begin{pmatrix} \sqrt{3} & -\frac{\sqrt{3}}{2} \\ 0 & \frac{5}{2} \end{pmatrix} \begin{pmatrix} 7 & \frac{3}{2} \\ \frac{3}{2} & 3 \end{pmatrix} \begin{pmatrix} \sqrt{3} & 0 \\ -\frac{\sqrt{3}}{2} & \frac{5}{2} \end{pmatrix} =
# \frac{4}{75} \begin{pmatrix} \frac{25\sqrt{3}}{4} & 0 \\ \frac{15}{4} & \frac{15}{2} \end{pmatrix} \begin{pmatrix} \sqrt{3} & 0 \\ -\frac{\sqrt{3}}{2} & \frac{5}{2} \end{pmatrix} =
# \frac{4}{75} \begin{pmatrix} \frac{75}{4} & 0 \\ 0 & \frac{75}{4} \end{pmatrix} = E
# $

# %% [markdown]
# ### 3. Найти ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами. Построить график плотности полученного распределения

# %% [markdown]
# $ \Sigma^{-1} = \begin{pmatrix} 3 & -\frac{3}{2} \\ -\frac{3}{2} & 7 \end{pmatrix} $
#
# \\
# Собственные числа матрицы:
#
# $ |\Sigma^{-1} - \lambda E| = \begin{vmatrix} 3 - \lambda & -\frac{3}{2} \\ -\frac{3}{2} & 7 - \lambda \end{vmatrix} = \lambda^2 - 10\lambda + \frac{75}{4} $
#
# $ \lambda_1 = \frac{5}{2}, \lambda_2 = \frac{15}{2} $
#
# \\
# Собственные вектора:
#
# $ \lambda_1 = \frac{5}{2} $
#
# $ \begin{pmatrix} \frac{1}{2} & -\frac{3}{2} \\ -\frac{3}{2} & \frac{9}{2} \end{pmatrix} \begin{pmatrix} v_{1,1} \\ v_{1,2} \end{pmatrix} = \begin{pmatrix} 0 \\ 0 \end{pmatrix} $
#
# $ \begin{pmatrix} v_{1,1} \\ v_{1,2} \end{pmatrix} = \begin{pmatrix} 3 \\ 1 \end{pmatrix} $
#
# $ v_1 = \begin{pmatrix} 3 \\ 1 \end{pmatrix} \cdot \frac{1}{\sqrt{10}} $
#
# \\
#
# $ \lambda_2 = \frac{15}{2} $
#
# $ \begin{pmatrix} -\frac{9}{2} & -\frac{3}{2} \\ -\frac{3}{2} & -\frac{1}{2} \end{pmatrix} \begin{pmatrix} v_{2,1} \\ v_{2,2} \end{pmatrix} = \begin{pmatrix} 0 \\ 0 \end{pmatrix} $
#
# $ \begin{pmatrix} v_{2,1} \\ v_{2,2} \end{pmatrix} = \begin{pmatrix} 1 \\ -3 \end{pmatrix} $
#
# $ v_2 = \begin{pmatrix} 1 \\ -3 \end{pmatrix} \cdot \frac{1}{\sqrt{10}} $
#
# \\
# $ Q^{t} = \frac{1}{\sqrt{10}} \begin{pmatrix} 3 & 1 \\ 1 & -3 \end{pmatrix} =>Q = \frac{1}{\sqrt{10}} \begin{pmatrix} 3 & 1 \\ 1 & -3 \end{pmatrix} $
#
# $ \begin{pmatrix} \xi_{ort} \\ \eta_{ort} \end{pmatrix} = Q \begin{pmatrix} \xi \\ \eta \end{pmatrix} = \frac{1}{\sqrt{10}} \begin{pmatrix} 3\xi + \eta \\ \xi - 3\eta \end{pmatrix} $
#
# $ E \begin{pmatrix} \xi_{ort} \\ \eta_{ort} \end{pmatrix} = \frac{1}{\sqrt{10}} \begin{pmatrix} 6 - 1 \\ -2 + 3 \end{pmatrix} = \frac{1}{\sqrt{10}} \begin{pmatrix} -7 \\ 1 \end{pmatrix} $
#
# \\
# Проверка:
#
# $ \Sigma_{ort} = \frac{1}{10} \cdot \frac{4}{75} \begin{pmatrix} 3 & 1 \\ 1 & -3 \end{pmatrix} \begin{pmatrix} 7 & \frac{3}{2} \\ \frac{3}{2} & 3 \end{pmatrix} \begin{pmatrix} 3 & 1 \\ 1 & -3 \end{pmatrix} = \frac{4}{750} \begin{pmatrix} \frac{45}{2} & \frac{15}{2} \\ \frac{5}{2} & -\frac{15}{2} \end{pmatrix} \begin{pmatrix} 3 & 1 \\ 1 & -3 \end{pmatrix} = \frac{4}{750} \begin{pmatrix} 75 & 0 \\ 0 & 25 \end{pmatrix} = \begin{pmatrix} \frac{2}{5} & 0 \\ 0 & \frac{2}{15} \end{pmatrix} $
#
# \\
# $ C = \frac{1}{2 \pi \sqrt{\frac{4}{75}}} = \frac{5\sqrt{3}}{4\pi} $
#
# $ p_{\xi_{ort},\eta_{ort}}(x,y) = \frac{5\sqrt{3}}{4\pi} \exp[-\frac{1}{2}\begin{pmatrix} x + \frac{7}{\sqrt{10}} \\ y - \frac{1}{\sqrt{10}} \end{pmatrix}^{t} \cdot \begin{pmatrix} \frac{5}{2} & 0 \\ 0 & \frac{15}{2} \end{pmatrix} \cdot \begin{pmatrix} x + \frac{7}{\sqrt{10}} \\ y - \frac{1}{\sqrt{10}} \end{pmatrix}] $

# %%
import numpy as np
import matplotlib.pyplot as plt

def p(x,y):
  return (5 * np.sqrt(3)) / (4 * np.pi) * np.exp(-0.5 * (2.5 * x**2 + 3.5 * np.sqrt(10) * x + 13 + 7.5 * y**2 - 1.5 * np.sqrt(10) * y))

x = np.linspace(-4, 0, 100)
y = np.linspace(-3, 3, 100)

X, Y = np.meshgrid(x,y)
Z = p(X,Y)

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection="3d")

ax.plot_surface(X, Y, Z, cmap = "plasma")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("Плотность распределения")
plt.show()

# %% [markdown]
# ### 4. Вычислить характеристики совместного распределения случайного вектора $ \begin{pmatrix} -\xi - 5\eta & 2\xi - 5\eta \end{pmatrix}^{t} $ и записать его плотность. Построить график плотности полученного распределения

# %% [markdown]
# $ A = \begin{pmatrix} -\xi - 5\eta \\ 2\xi - 5\eta \end{pmatrix} = \begin{pmatrix} -1 & -5 \\ 2 & -5 \end{pmatrix} \begin{pmatrix} \xi \\ \eta \end{pmatrix} = \begin{pmatrix} \xi_4 \\ \eta_4 \end{pmatrix} $
#
# $ \det A  = 5 + 2 \cdot 5 = 15 \ne 0 $
#
# $ E \begin{pmatrix} \xi_4 \\ \eta_4 \end{pmatrix} = \begin{pmatrix} -1 & -5 \\ 2 & -5 \end{pmatrix} \begin{pmatrix} -2 \\ -1 \end{pmatrix} = \begin{pmatrix} 7 \\ 1 \end{pmatrix} $
#
# $ \Sigma_4 = \frac{4}{75} \begin{pmatrix} -1 & -5 \\ 2 & -5 \end{pmatrix} \begin{pmatrix} 7 & \frac{3}{2} \\ \frac{3}{2} & 3 \end{pmatrix} \begin{pmatrix} -1 & 2 \\ -5 & -5 \end{pmatrix} = \frac{4}{75} \begin{pmatrix} -\frac{29}{2} & -\frac{33}{2} \\ \frac{13}{2} & -12 \end{pmatrix} \begin{pmatrix} -1 & 2 \\ -5 & -5 \end{pmatrix} = \frac{4}{75} \begin{pmatrix} 97 & \frac{107}{2} \\ \frac{107}{2} & 73 \end{pmatrix} $
#
# $ D_{\xi_4} = \frac{4}{75} \cdot 97 $
#
# $ D_{\eta_4} = \frac{4}{75} \cdot 73 $
#
# $ cov(\xi,\eta) = \frac{4}{75} \cdot \frac{107}{2} = \frac{214}{75} $
#
# $ \rho(\xi, \eta) = \frac{214}{75 \sqrt{\frac{4}{75} \cdot 97 \cdot \frac{4}{75} \cdot 73} } = \frac{107}{2 \sqrt{97 \cdot 73}} $
#
# \\
# $ C = \frac{1}{2\pi \sqrt{12}} = \frac{\sqrt{3}}{12\pi} $
#
# $ \Sigma_{4}^{-1} = \frac{4}{75} \cdot \frac{1}{12} \begin{pmatrix} 73 & -\frac{107}{2} \\ -\frac{107}{2} & 97 \end{pmatrix} = \begin{pmatrix} \frac{73}{225} & -\frac{107}{450} \\ -\frac{107}{450} & \frac{97}{225} \end{pmatrix} $
#
# $ p_{\xi_{4},\eta_{4}}(x,y) = \frac{\sqrt{3}}{12\pi} \exp[-\frac{1}{2}\begin{pmatrix} x - 7 \\ y - 1 \end{pmatrix}^{t} \cdot \begin{pmatrix} \frac{73}{225} & -\frac{107}{450} \\ -\frac{107}{450} & \frac{97}{225} \end{pmatrix} \cdot \begin{pmatrix} x - 7 \\ y - 1 \end{pmatrix}] $

# %%
import numpy as np
import matplotlib.pyplot as plt

def p(x,y):
  return np.sqrt(3) / (12 * np.pi) * np.exp(-0.5 * ( (73/225) * x**2 - (61/15) * x + 13 - (107/225) * x * y + (37/15) * y + (97/225) * y**2))

x = np.linspace(-4, 14, 100)
y = np.linspace(-6, 12, 100)

X, Y = np.meshgrid(x,y)
Z = p(X,Y)

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection="3d")

ax.plot_surface(X, Y, Z, cmap = "plasma")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("Плотность распределения")
plt.show()

# %% [markdown]
# ### 5. Найти условное распределение $ \xi $ при условии $ \eta $. Вычислить $ E(\xi|\eta) $ и $ D(\xi|\eta) $

# %% [markdown]
# $E\eta = -1$
#
# $D\eta = \frac{12}{75}$
#
# $C = \frac{1}{2\pi \cdot \sqrt{\detΣ}} = \frac{1}{2\pi\sqrt{\frac{12}{75}}} = \frac{1}{2\pi \frac{2}{5}} = \frac{5}{4\pi} $
#
# $p_{\eta}(y) = \frac{5}{4\pi} \cdot \exp[-\frac{1}{2}\begin{pmatrix} y + 1 \end{pmatrix} \cdot \begin{pmatrix} \frac{75}{12} \end{pmatrix} \cdot \begin{pmatrix} y + 1 \end{pmatrix}] = \frac{5}{4\pi} \cdot \exp( -\frac{1}{2} \cdot \frac{1}{4} (25y^2 + 50y + 25)) $
#
# \\
# $ p_{\xi|\eta=y}(x) = \frac{p_{\xi,\eta}(x,y)}{p_{\eta}(y)} = \frac{ \frac{5 \sqrt{3}}{4\pi} \cdot \exp(-\frac{1}{2} (3x^2 - 3xy + 7y^2 + 9x + 8y + 13))}{\frac{5}{4\pi} \cdot \exp( -\frac{1}{2} \cdot \frac{1}{4} (25y^2 + 50y + 25))} = \sqrt{3} \cdot \exp[-\frac{1}{2}(3x^2 - 3xy + 7y^2 + 9x + 8y + 13) - \frac{-1}{2} \cdot \frac{1}{4} (25y^2 + 50y + 25)] = \sqrt{3} \cdot \exp[ -\frac{1}{2} (3x^2 - 3xy + \frac{3}{4}y^2 + 9x - \frac{9}{2}y + \frac{27}{4}) ] = \sqrt{3} \cdot \exp[ -\frac{1}{2} (3(x^2 - 2x(\frac{y}{2} - \frac{3}{2})) + 3(\frac{y^2}{4} - \frac{3y}{2} + \frac{9}{4})) ] = \sqrt{3} \cdot \exp[ -\frac{3}{2} (x - (\frac{y}{2} - \frac{3}{2}))^2 ] $
#
# \\
# $ E(\xi|\eta=y) = \frac{y}{2} - \frac{3}{2} $
#
# $ D(\xi|\eta=y) = \frac{1}{3} $

# %% [markdown]
# ## Выводы
#
# По итогу лабораторной работы исследованы свойства двумерного случайного вектора, имеющего нормальное распределение. Приобретены навыки преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.
#
# Вычислен вектор математических ожиданий и ковариационных характеристик для данного случайного вектора; найдено аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный; найдено ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами; вычислены характеристики совместного распределения случайного вектора; найдено условное распределение и соответствующие ему характеристики. Построены графики полученных распределений с использованием Python.
