# %% [markdown]
# # Практическая работа №3: Регрессионный анализ
# Выполнил студент гр. 1384 Феопентов Аким. Вариант №19

# %% [markdown]
# ## Цель работы
#
# Ознакомление с основными положениями метода наименьших квадратов (МНК), со статистическими свойствами МНК-оценок, с понятием функции регрессии и роли МНК в регрессионном анализе.

# %% [markdown]
# ## Основные теоретические положения
#
# 1. Линейная регрессионная модель
#
#     Линейная регрессия некоторой зависимой переменной y на набор независимых переменных  x = (x_1, …, x_n), где n – это число наблюдений, предполагает, что линейное отношение между y и x: $y =\beta_0  + \beta_1x_1 + ⋯ + \beta_nx_n + 𝜀$ - уравнение регрессии. $\beta_0, \beta_1, …, \beta_n$ – коэффициенты регрессии (параметры), и 𝜀 – случайная ошибка.
#
# 2. МНК (Метод Наименьших Квадратов)
#
#     $RSS(\beta)=\left\| Y-X^{\intercal}\beta \right\|=(Y-X^{\intercal}\beta)^{\intercal}\cdot(Y-X^{\intercal}\beta)\to min\beta$
#
#     Нормальные уравнения: $XX^{\intercal}\beta=XY$
#
#     Решение системы нормальных уравнений в регулярном случае: $\widehat{\beta}=(XX^{\intercal})^{-1}XY$
#
#     $RSS(\beta)=\sum_{i=1}^{n}\left( Y_{i}-\sum_{j=1}^{m}x_{ji}\beta_{j} \right)^{2}$
#
#     $\frac{\partial RSS}{\partial \beta_{k}} = -2\sum_{i=1}^{n}x_{ki}\left(Y_{i}- \sum_{j=1}^{m}x_{ji}\beta_{j}\right)=0, k=\overline{1,m}$
#
# 3. Несмещённая оценка дисперсии $(S^{2})$
#
#     $S^{2} = \frac{SS_{e}}{n-r} = \frac{RSS(\widehat{\beta})}{n-r}$
#
#     $SS_{e}=RSS(\widehat{\beta})$, а r-ранг матрицы X
#
# 4. Доверительный интервал
#
#     ДНО функции:$\psi=C^{\intercal}\beta$\
#     МНК-оценка: $\widehat{\psi}=C^{\intercal}\beta$\
#     \
#     Элемент дисперсии оценки: $b_{\psi}=C^{\intercal}(XX^{\intercal})^{-1}C$\
#     Распределение $\widehat{\psi} \sim \mathcal{N}(\psi,\sigma^{2}b)$\
#     $\displaystyle \frac{\widehat{\psi}-\psi}{S\sqrt{b}} \sim \mathcal{S}_{n-r}$\
#     \
#     Доверительный интервал уровня доверия $1-\alpha: \left[ \widehat{\psi} - X_{\alpha}S\sqrt{b},\widehat{\psi} + X_{\alpha}S\sqrt{b} \right]$,\
#     где $\displaystyle X_{\alpha}: \mathcal{S}_{n-r}(X_{\alpha})=1-\frac{\alpha}{2}$
#
# 5. Уравнение $A_{\alpha}=\left\{ \overrightarrow{X}:(\overrightarrow{X}-\widehat{\psi})^{\intercal}B^{-1}(\overrightarrow{X}-\widehat{\psi})\le qS^{2}X_{\alpha} \right\}$ представляет собой уравнение доверительного эллипсоида. Здесь:
#
#     - $\widehat{\psi}$ - вектор оценок параметров,
#     - $B$ - матрица оценок ковариации,
#     - $S^{2}$ - оценка дисперсии,
#     - q - пороговая точка, связанная с распределением хи-квадрат с \(n-r\) степенями свободы,
#     - $X_{\alpha}$ - значение функции распределения хи-квадрат с (n-r) степенями свободы и уровнем доверия $1-\alpha$.
#
# 6. Критерий $\chi^2$ для проверки гипотез
#
#     основан на справнении теоритической плотности распределения и гистограммы, либо теоритической вероятностной меры и полигона частот.
#
#     Разобъем множество значений сл. вел. X на $N$ интервалов $I_{1}, ..., I_{N}:$ $I_{i} = (a_{i-1}, a_i], i = \overline {1,N}$. данные интервалы не пересекаются и покрывают всё множество возможных значений сл. вел. X.
#
#     Обозначим через $p_{i}$ теоритическую вероятность попадания сл. вел. X в интервал $I_{i}$, при условии, что справедлива $H_{0}$.
#
#     $p_{i} = P(X \in I_{i}|H_{0})$
#
#     Через $n_{i}$ обозначим число наблюдений нашей выборки, попавших в соответветствующий интервал $I_{i}$.
#
#     $n_{i} = \sum \limits_{i=1}^{n}\mathbb{1}(x_{j} \in I_{i})$
#
#     Статистика критерия основана на сравнении относительной частоты и теоритической.
#
#     $\chi^{2}_{набл} = \sum \limits_{i=1}^{N} \frac{n}{p_{i}} \bigg ( \frac{n_{i}}{n} - p_{i} \bigg )^{2} = \sum \limits_{i=1}^{N} \frac{(n_{i} - p_{i} n)^{2}}{n p_{i}} \sim \chi^{2}_{N-1}$
#
#     Если $\mathcal{X}^{2}_{N-1,1-\alpha_{1}} \lt \chi^2_{набл}$, то гипотезу отвергаем
#
#     Если $\mathcal{X}^{2}_{N-1,1-\alpha_{1}} \gt \chi^2_{набл}$, то гипотезу принимаем
#
# 7. Теорема Колмогорова
#
#     $D_{n}(\overrightarrow{X}) = \overset{}{\underset{X \in \mathbb R}{sup}} |F_{0}(X_{i}) - F_{n}(X_{i})|$
#
#     Если гипотеза $H_{0}$ верна, и $F_{0}(X)$ - непрерывная ф-я на $\mathbb R$, тогда имеет место сходимость
#
#     $P(\sqrt{n} D_{n}(\overrightarrow{X}) < z) \xrightarrow[n \rightarrow \infty]{} K(z)$, где
#
#     $K(z)=1-\alpha$ - ф-я распределения Колмогорова.
#
#     Если $D_{n} \lt z$, то гипотезу принимаем
#
#     Если $D_{n} \gt z$, то гипотезу отвергаем

# %% [markdown]
# ## Постановка задачи
# Результаты статистического эксперимента представлены в виде двух переменных. Требуется оценить характер (случайной) зависимости переменной Y от переменной X. Полученные результаты содержательно проинтерпретировать.
#
# Результаты статистического эксперимента приведены в таблице 1. Требуется оценить характер (случайной) зависимости переменной У от переменной Х.
#
# 1. Построить графически результаты эксперимента. Сформулировать линейную регрессионную модель переменной У по переменной Х. Построить МНК оценки параметров сдвига $\beta_0$ и масштаба $\beta_1$. Построить полученную линию регрессии. Оценить визуально соответствие полученных данных и построенной оценки.
#
# 2. Построить и интерпретировать несмещённую оценку дисперсии. На базе ошибок построить гистограмму с шагом $h$. Проверить гипотезу нормальности ошибок на уровне значимости $\alpha$ по $\chi^2$. Оценить расстояние полученной оценки до класса нормальных распределений по Колмогорову. Визуально оценить данный факт.
#
# 3. В предположении нормальности ошибок построить доверительные интервалы для параметров $\beta_0$ и $\beta_1$ уровня доверия $1 - \alpha$. Построить доверительный эллипс уровня доверия $1 - \alpha$ для $(\beta_0, \beta_1)$ (вычислить его полуоси).
#
# 4. Сформулировать гипотезу независимости переменной У от переменной Х. Провести проверку значимости.
#
# 5. Сформулировать модель, включающую дополнительный член с $X^2$. Построить МНК оценки параметров $\beta_0$, $\beta_1$, $\beta_2$ в данной модели. Изобразить графически полученную регрессионную зависимость.
#
# 6. Построить несмещённую оценку дисперсии. Провести исследование нормальности ошибок как в пункте 2.
#
# 7. В предположении нормальности ошибок построить доверительные интервалы для параметров $\beta_0, \beta_1, \beta_2$ уровня доверия $1 - \alpha$. Написать уравнение доверительного эллипсоида уровня доверия $1 - \alpha$.
#
# 8. Сформулировать гипотезу линейной регрессионной зависимости переменной Y от переменной Х и проверить её значимость на уровне $\alpha$.
#
# 9. Интерпретировать полученные результаты. Написать отчёт.
#
# $\alpha = 0.02$; $h = 0.79$

# %% [markdown]
# ## Выполнение работы

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.optimize import minimize
from math import factorial
import scipy.stats as sps
import scipy.optimize as spo
import numpy as np
import scipy
import scipy.stats as stats
import matplotlib.pyplot as plt
from scipy.stats import chi2

# %% [markdown]
# ### Задание 1

# %% [markdown]
# #### 1) Построить графически результаты эксперимента. Сформулировать линейную регрессионную модель переменной У по переменной Х. Построить МНК оценки параметров сдвига $\beta_0$ и масштаба $\beta_1$. Построить полученную линию регрессии. Оценить визуально соответствие полученных данных и построенной оценки.

# %%
X = np.array([3, 2, 3, 2, 2, 3, 0, 0, 1, 1, 3, 0, 0, 2, 0, 0, 0, 3, 1, 3, 3, 1, 2, 2, 2, 3, 1, 2, 3, 0, 1, 2, 1, 1, 3, 0, 1, 2, 3, 2, 2, 3, 3, 3, 1, 0, 0, 2, 2, 1])
Y = np.array([7.23, 8.21, 8.21, 8.93, 8.60, 7.25, 8.38, 8.83, 8.02, 8.72, 8.61, 7.23, 8.87, 7.61, 8.91, 8.45, 8.17, 7.59, 8.28, 7.63, 7.36, 7.15, 7.47, 7.54, 8.09, 7.81, 8.17, 7.46, 6.46, 8.55, 7.37, 8.02, 9.13, 8.69, 7.37, 8.36, 6.00, 6.48, 7.80, 8.54, 7.70, 7.65, 6.79, 6.96, 8.01, 6.82, 8.20, 7.20, 9.73, 8.19])

# %% [markdown]
# Регрессонная модель
#
# $Y = \beta_0 + \beta_1 X + \mathbb \varepsilon$
#
# Построим график

# %%
plt.scatter(X, Y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Результаты эксперимента')
plt.show()

# %% [markdown]
#  1)$\mathbb{E}_\theta e = 0$
#
#  2)$Var_\theta e = \sigma^2 E$
#
# 1-2 следуют из регрессионной модели
#
# Система нормальных уравнений
# $ X X^T \beta = X Y $
#
# МНК оценка:
#
# $ \hat{\beta} = (X X^T)^{-1} XY $

# %%
X_rez = np.array([[1 for i in range(50)], X])
Y_rez = np.array(Y)
XXT = np.dot(X_rez, np.transpose(X_rez))
print("XXT: ", XXT)
XY = np.dot(X_rez, Y_rez)
print("XY: ", XY)
beta = np.dot(np.linalg.inv(XXT), XY)

print("b0:", round(beta[0], 3), "b1:", round(beta[1], 3))
# Out:
# XXT:  [[ 50  81]
#  [ 81 193]]
# XY:  [394.8  625.05]
# b0: 8.277 b1: -0.235

# %% [markdown]
# Наложим на график с исходными данными линейную регрессию

# %%
plt.plot(X, Y, 'o')
model_line = np.dot(X_rez.T, beta)
plt.title('Линия регрессии и исходные данные')
plt.plot(X, model_line, 'o-', color='red', label='Model')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #### 2) Построить и интерпретировать несмещенную оценку дисперсии. На базе ошибок построить гистограмму с шагом h =0.79  Проверить гипотезу нормальности ошибок на уровне значимости $\alpha$ = 0.02 по $\chi^2$. Оценить расстояние полученной оценки до класса нормальных распределений по Колмогорову. Визуально оценить данный факт.
#
# оценка параметра $s^2 =\frac{RSS(\hat{\beta})}{(n - r)}= \frac{1}{n-r} \cdot  (Y - X^T \widehat \beta)^T (Y - X^T \widehat \beta) $, где $r = rank(X) = 2$ <br>
# $s^2 = 0.521$

# %%
s = np.dot((Y_rez - np.dot(X_rez.T, beta)).T, (Y_rez - np.dot(X_rez.T, beta)))/(len(Y)-2)
print("Несмещенная оценка дисперсии: ", s)
# Out:
# Несмещенная оценка дисперсии:  0.5213162404230063

# %%
Y_graphic = beta[0] + beta[1] * X_rez[1]
err = Y_rez - Y_graphic
h = 0.79
hist, bins, _ = plt.hist(err, bins=np.arange(min(err), max(err) + h, h), edgecolor='black', color='b')
plt.xlabel('Ошибки')
plt.ylabel('Частота')
plt.title('Оценки ошибок')
plt.show()
for i in range(len(hist)):
    print(f' Интервал {i}: ({round(bins[i], 4)}, {round(bins[i+1], 4)}), количество чисел попавших в интервал: {hist[i]}')
# Out:
#  Интервал 0: (-2.0418, -1.2518), количество чисел попавших в интервал: 3.0
#  Интервал 1: (-1.2518, -0.4618), количество чисел попавших в интервал: 7.0
#  Интервал 2: (-0.4618, 0.3282), количество чисел попавших в интервал: 27.0
#  Интервал 3: (0.3282, 1.1182), количество чисел попавших в интервал: 11.0
#  Интервал 4: (1.1182, 1.9082), количество чисел попавших в интервал: 1.0
#  Интервал 5: (1.9082, 2.6982), количество чисел попавших в интервал: 1.0

# %% [markdown]
# Гипотеза на уровне значимости $\alpha = 0.02$
#
# Основная гипотеза: $H_0 \sim \mathcal{N}(0, \sigma^2)$
#
# Переопределим интервалы, чтобы в каждом было не менее 5 значений:
#
# $I_1 = (-\infty, -0.4618], \; v_1 = 10$
#
# $I_2 = (-0.4618,  0.3282], \; v_2 = 27$
#
# $I_3 = (0.3282, \infty), \; v_3 = 13$
#
# Посчитаем статистику критерия $\chi^2$:
#
# Статистика критерия: $\chi^2 = \sum_{j=1}^{k}\frac{ (\nu_j - np_{jo})^2 }{ np_{j0} }$, где k - количество интервалов
#
# Квантиль $x_{\alpha}:$ $ \mathcal{K}_{1}(x_a) = 1 - \alpha_1 = 1 - 0.02 = 0.98$

# %%
def minSum(a, g):
  array = [-0.4618,0.3282]
  res = [0] * (len(array) + 1)
  res[0] = sps.norm.cdf(array[0], a, g)
  res[1] = sps.norm.cdf(array[1], a, g) - sps.norm.cdf(array[0], a, g)
  res[2] = 1 - sps.norm.cdf(array[1], a, g)
  res = [round(elem, 5) for elem in res]
  v = [10, 27, 13]
  ans = [(v[i] - 50 * res[i]) ** 2 / (50 * res[i]) for i in range(len(v))]
  ans = [round(elem, 3) for elem in ans]
  return sum(ans)
print("X^2 =", minSum(0, s ** 0.5))
alpha = 0.02
x_alpha = stats.chi2(1).ppf(1 - alpha)
print(f'Квантиль x_alpha: {round(x_alpha, 4)}')
a_max = 1 - chi2.cdf(minSum(0, s ** 0.5), 1)
print("Максимальный уровень значимости alpha, при котором может быть принята гипотеза:", a_max)
# Out:
# X^2 = 3.277
# Квантиль x_alpha: 5.4119
# Максимальный уровень значимости alpha, при котором может быть принята гипотеза: 0.07025724373542519

# %% [markdown]
# $\chi^2 < x_\alpha \Rightarrow$ принимаем $H_0$
#
# Теперь оценим гипотезу при помощи распределения Колмагорова.
#
# $ \sqrt{n} \cdot max|F_n(y) - F(y)| \sim K $,  $K$ - распределение Колмогорова.

# %%
n = len(X)
def createFn(x, values):
    sum = 0
    for i in values:
        if i >= x:
            return sum / n
        sum += 1
    return sum / n
v = np.arange(np.min(err) - h, np.max(err) + h, h)
Fn = np.array([createFn(i, np.sort(err)) for i in v])
F = np.array([stats.norm.cdf(y, 0, np.sqrt(s)) for y in v])
Dn = np.max(np.abs(Fn - F)) * np.sqrt(n)
print("Dn: ", Dn)
x_alpha = stats.ksone.ppf(1 - alpha, n)
print("x_alpha: ", x_alpha)
# Out:
# Dn:  0.4575179899983797
# x_alpha:  0.19407039031413997

# %% [markdown]
# $Dn > x_\alpha \Rightarrow$ основная гипотеза отвергается

# %%
plt.title('Функции выборочной функции распределения ошибки и нормального распределения')
plt.xlabel('x') 
plt.ylabel('Значения функций')
plt.plot(v, F, color='red')
plt.plot(v, Fn, color='blue')
plt.show()
plt.show()

# %% [markdown]
# #### 3. В предположении нормальности ошибок построить доверительные интервалы для параметров $\beta_0$ и $\beta_1$ уровня доверия $1-\alpha$. Построить доверительный эллипс уровня доверия $1-\alpha$ для $(\beta_0, \beta_1)$ (вычислить его полуоси).
#
# ДНО функция: $\psi = C^T \beta $
#
# Элемент дисперсии оценки: $ b_\psi = C^T (XX^T)^{-1}C$, где  $C$ - матрица для опеределения параметров, которые будут оценены.
#
# Тогда для построения доверительного интервала: $ \cfrac{\widehat \psi - \psi}{s\sqrt{b}} \sim S_{n-r} $
#
# Доверительный интервал уровня доверия $1 - \alpha$:
#
# $ P_\theta(-x_\alpha \le \cfrac{\widehat \psi - \psi}{s\sqrt{b}} \le x_\alpha) = 1 -\alpha $, <br>
# где квантиль $ x_\alpha : S_{n-r}(x_\alpha) = 1 -\frac{\alpha}{2} $
#
# $b_{\psi_0} = C_0^T (X X^T)^{-1} C_0 = 0.0625$
#
#
# $b_{\psi_1} = C_1^T (X X^T)^{-1} C_1 = 0.0162$
#
# Найдем $x_{\alpha} = S^{-1}_{n - 2}(1 - \frac{\alpha}{2}) = 2.407$

# %%
x_alpha = stats.t.ppf(1-alpha/2, n-2)
print("x_alpha: ", round(x_alpha, 3))
b_0 = np.dot(np.dot(np.array([1, 0]).T, np.linalg.inv(XXT)),np.array([1, 0]))
print("b0:", round(b_0, 3))
b_1 = np.dot(np.dot(np.array([0, 1]).T,np.linalg.inv(XXT)), np.array([0, 1]))
print("b1: ", round(b_1, 3))
print(f'Доверительный интервал [{round(beta[0] - x_alpha * np.sqrt(s) * np.sqrt(b_0), 3)}, {round(beta[0] + x_alpha * np.sqrt(s) * np.sqrt(b_0), 3)}] для beta_0')
print(f'Доверительный интервал [{round(beta[1] - x_alpha * np.sqrt(s) * np.sqrt(b_1), 3)}, {round(beta[1] + x_alpha * np.sqrt(s) * np.sqrt(b_1), 3)}] для beta_1')
# Out:
# x_alpha:  2.407
# b0: 0.062
# b1:  0.016
# Доверительный интервал [7.843, 8.711] для beta_0
# Доверительный интервал [-0.456, -0.014] для beta_1

# %% [markdown]
# Доверительный эллипсоид уровня доверия 1 - $\alpha$ :
#
# $ A_\alpha = \{x: (x - \widehat \psi)^T (C^T (XX^T)^{-1}C)^{-1}(x - \widehat \psi) \le qs^2x_\alpha\}$, где $ x_\alpha = F_{q, n-r}(x_\alpha) = 1 - \alpha$
#
# $C = \begin{pmatrix}
#     1 & 0\\
#     0 & 1
# \end{pmatrix} $
#
# В качестве вектора возьмем $ \vec{x}= P(\hat{\psi} - \psi) $, где P - матрица собственных векторов
#
# Уравнение элипсойда
#
# $(\widehat \psi -  \psi)^T (C^T (XX^T)^{-1}C)^{-1}(\widehat \psi -  \psi) = \lambda_1 x^2 + \lambda_2 y^2 \le qs^2x_\alpha$, где $\lambda_1$ и $\lambda_2$ - собственные числа матрицы $XX^T$
#
# $\cfrac{\lambda_1}{qs^2x_\alpha}x^2 + \cfrac{\lambda_2}{qs^2x_\alpha}y^2 \le 1$
#
# Большая и малая полуоси могут быть вычислены как $ \frac{q s^2 x_{\alpha}}{\lambda_1} $ и $ \frac{q s^2 x_{\alpha}}{\lambda_2} $ соответственно.
#
# $ \vec{x}= P(\hat{\psi} - \psi) = \begin{pmatrix} x\\ y \end{pmatrix} = \begin{pmatrix} -0.91153022 && -0.4112331 \\ 0.4112331 && -0.91153022 \end{pmatrix} \cdot \begin{pmatrix} 8.27690191 - \beta_0 \\ -0.23512464 - \beta_1 \end{pmatrix}$

# %%
evalues, evectors = np.linalg.eig(XXT)
x_alpha = stats.f.ppf(1-alpha, 2, n-2)
print("x_alpha: ", x_alpha)

a = np.sqrt((2 * s * x_alpha) / evalues[0])
b =  np.sqrt((2 * s * x_alpha) / evalues[1])

print("Большая полуось: ", round(a, 3))
print("Малая полуось: ", round(b, 3))

print("beta: ", beta)

def ellipse_equation(beta0, beta1):
    return (( evectors[0][0] * (beta[0] - beta0) - evectors[0][1] * (beta[1] - beta1))**2 / a**2) + ((evectors[1][0] * (beta[0] - beta0) + evectors[1][1] * (beta[1] - beta1))**2 / b**2)


print("Собственные вектора: ", evectors)
print("Собственные числа: ", evalues)
x = np.linspace(5, 10, 200)
y = np.linspace(-1, 1, 200)
X_rez, Y_rez = np.meshgrid(x, y)
plt.figure(figsize=(6, 6))
plt.contour(X_rez, Y_rez,ellipse_equation(X_rez, Y_rez), levels=[1], colors='blue', linewidths=2)

plt.title("Эллипс")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()
# Out:
# x_alpha:  4.248907630769176
# Большая полуось:  0.574
# Малая полуось:  0.139
# beta:  [ 8.27690191 -0.23512464]
# Собственные вектора:  [[-0.91153022 -0.4112331 ]
#  [ 0.4112331  -0.91153022]]
# Собственные числа:  [ 13.45718441 229.54281559]

# %% [markdown]
# #### 4) Сформулировать гипотезу независимости переменной Y от переменной X. Провести проверку значимости.
# ДНО - функция:
# $\psi = C^T \beta $
#
#
# Основная гипотеза:
# $ H_0 : \beta_1 = 0$
#
# Y не зависит от X, если $ y_i \approx \beta_0 + \beta_1 x_i = \beta_0 $\
# То есть $ \beta_1 = 0 $
#
# $ C = \left( \begin{array}{c} 0 \\ 1 \end{array} \right) \implies \psi = \left( \begin{array}{c} 0 & 1 \end{array} \right) \left( \begin{array}{c} \beta_0 \\ \beta_1 \end{array} \right) = \beta_1$
#
# $\mathcal{F} = \cfrac{\widehat \psi^T ((C^T (XX^T)^{-1}C)^{-1}) \widehat \psi}{qs^2} \sim F_{q, n-r}$
#
# $\mathcal{F} = \cfrac{{\widehat \beta_1} ^2}{bqs^2} $
#
# $x_\alpha: F_{q, n-r}(x_\alpha) = 1 - \alpha $

# %%
b = np.dot(np.dot( np.array([0, 1]).T, np.linalg.inv(XXT)),  np.array([0, 1]))
print("b: ", round(b, 3))
F = beta[1] ** 2 / (b * 1 * s)
print("F: ", round(F, 3))
print("alpha: ", alpha)
x_alpha = stats.f(1, n - 2).ppf(1 - alpha)
print("x_alpha: ", round(x_alpha, 4))
a_max = 1 - stats.f.cdf(F, 1, n - 2)
print("Максимальный уровень значимости alpha, при котором может быть принята гипотеза:", a_max)
# Out:
# b:  0.016
# F:  6.552
# alpha:  0.02
# x_alpha:  5.7916
# Максимальный уровень значимости alpha, при котором может быть принята гипотеза: 0.013684493831422118

# %% [markdown]
#  $\mathcal{F} > x_\alpha$, отвергаем $H_0$

# %% [markdown]
# #### 5) Сформулировать модель, включающую дополнительный член $X^2$. Построить МНК оценки параметров $\beta_0, \beta_1, \beta_2$ в данной модели. Изобразить полученную регрессионную зависимость.
#  1)$\mathbb{E}_\theta e = 0$
#
#  2)$Var_\theta e = \sigma^2 E$
#
# 1-2 следуют из регрессионной модели
#
# Система нормальных уравнений
# $ X X^T \beta = X Y $
#
# МНК оценка:
#
# $ \hat{\beta} = (X X^T)^{-1} XY $

# %% [markdown]
# $Y = \beta_0 + \beta_1 X + \beta_1X^2 + \mathbb \varepsilon$
#
# $\beta = (\beta_0, \beta_1, \beta_2) $

# %%
X_rez = np.array([[1 for i in range(50)], X, [i**2 for i in X]])
Y_rez = np.array(Y)
XXT = np.dot(X_rez, np.transpose(X_rez))
print("XXT: ", XXT)
XXT_inv = np.linalg.inv(XXT)
print("XXT_inv: ", XXT_inv)
beta = np.dot(np.dot(XXT_inv, X_rez), Y_rez)

print("b0:", round(beta[0], 3), "b1:", round(beta[1], 3), "b2:", round(beta[2], 3))
# Out:
# XXT:  [[  50   81  193]
#  [  81  193  501]
#  [ 193  501 1369]]
# XXT_inv:  [[ 0.08581818 -0.09218182  0.02163636]
#  [-0.09218182  0.2026039  -0.06114935]
#  [ 0.02163636 -0.06114935  0.02005844]]
# b0: 8.21 b1: -0.045 b2: -0.062

# %%
plt.plot(X, Y, 'o')
X_graph = np.array([[1 for i in range(50)], np.sort(X), [i**2 for i in np.sort(X)]])
model_line = np.dot(np.transpose(X_graph), beta)
plt.title('Линия регрессии и исходные данные')
plt.plot(np.sort(X), model_line, 'o-', color='red', label='Model')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #### 6) Построить несмещенную оценку дисперсии. Провести исследование нормальности ошибок как в пункте 2.
#
# оценка параметра $s^2 =\frac{RSS(\hat{\beta})}{(n - r)}= \frac{1}{n-r} \cdot  (Y - X^T \widehat \beta)^T (Y - X^T \widehat \beta) $, где $r = rank(X) = 3$
#
# $s^2 = 0.55$

# %%
s = np.dot((Y_rez - np.dot(X_rez.T, beta)).T, (Y_rez - np.dot(X_rez.T, beta)))/(len(Y)-3)
print("Несмещенная оценка дисперсии: ", s)
# Out:
# Несмещенная оценка дисперсии:  0.5282679721470019

# %%
Y_graphic = beta[0] + beta[1] * X_rez[1] + beta[2]*X_rez[1]**2
err = Y_rez - Y_graphic
h = 0.79
hist, bins, _ = plt.hist(err, bins=np.arange(min(err), max(err) + h, h), edgecolor='black', color='b')
plt.xlabel('Ошибки')
plt.ylabel('Частота')
plt.title('Оценки ошибок')
plt.show()
for i in range(len(hist)):
    print(f' Интервал {i}: ({round(bins[i], 4)}, {round(bins[i+1], 4)}), количество чисел попавших в интервал: {hist[i]}')
# Out:
#  Интервал 0: (-2.1024, -1.3124), количество чисел попавших в интервал: 3.0
#  Интервал 1: (-1.3124, -0.5224), количество чисел попавших в интервал: 7.0
#  Интервал 2: (-0.5224, 0.2676), количество чисел попавших в интервал: 24.0
#  Интервал 3: (0.2676, 1.0576), количество чисел попавших в интервал: 13.0
#  Интервал 4: (1.0576, 1.8476), количество чисел попавших в интервал: 2.0
#  Интервал 5: (1.8476, 2.6376), количество чисел попавших в интервал: 1.0

# %% [markdown]
# Гипотеза на уровне значимости $\alpha = 0.02$
#
# Основная гипотеза: $H_0 \sim \mathcal{N}(0, \sigma^2)$
#
# Переопределим интервалы, чтобы в каждом было не менее 5 значений:
#
# $I_1 = (-\infty, -0.5224], \; v_1 = 10$
#
# $I_2 = (-0.5224,  0.2676], \; v_2 = 24$
#
# $I_3 = (0.2676, \infty), \; v_3 = 16$
#
# Посчитаем статистику критерия $\chi^2$:
#
# Статистика критерия: $\chi^2 = \sum_{j=1}^{k}\frac{ (\nu_j - np_{jo})^2 }{ np_{j0} }$, где k - количество интервалов
#
# Квантиль $x_{\alpha}:$ $ \mathcal{K}_{0}(x_a) = 1 - \alpha_1 = 1 - 0.02 = 0.98$

# %%
def minSum(a, g):
  array = [-0.5224,0.2676]
  res = [0] * (len(array) + 1)
  res[0] = sps.norm.cdf(array[0], a, g)
  res[1] = sps.norm.cdf(array[1], a, g) - sps.norm.cdf(array[0], a, g)
  res[2] = 1 - sps.norm.cdf(array[1], a, g)
  res = [round(elem, 5) for elem in res]
  v = [10, 24, 16]
  ans = [(v[i] - 50 * res[i]) ** 2 / (50 * res[i]) for i in range(len(v))]
  ans = [round(elem, 3) for elem in ans]
  return sum(ans)
print("X^2 =", minSum(0, s ** 0.5))
alpha = 0.02
x_alpha = stats.chi2(1).ppf(1 - alpha)
print("Квантиль x_alpha: ", round(x_alpha, 3))
a_max = 1 - chi2.cdf(minSum(0, s ** 0.5), 1)
print("Максимальный уровень значимости alpha, при котором может быть принята гипотеза:", a_max)
# Out:
# X^2 = 1.108
# Квантиль x_alpha:  5.412
# Максимальный уровень значимости alpha, при котором может быть принята гипотеза: 0.2925171176780179

# %% [markdown]
# $\chi^2 < x_\alpha \Rightarrow$ принимаем $H_0$
#
# Теперь оценим гипотезу при помощи распределения Колмагорова.
#
# $ \sqrt{n} \cdot max|F_n(y) - F(y)| \sim K $,  $K$ - распределение Колмогорова.

# %%
n = len(X)
def createFn(x, values):
    sum = 0
    for i in values:
        if i >= x:
            return sum / n
        sum += 1
    return sum / n
v = np.arange(np.min(err) - h, np.max(err) + h, h)
Fn = np.array([createFn(i, np.sort(err)) for i in v])
F = np.array([stats.norm.cdf(y, 0, np.sqrt(s)) for y in v])
Dn = np.max(np.abs(Fn - F)) * np.sqrt(n)
print("Dn: ", Dn)
x_alpha = stats.ksone.ppf(1 - alpha, n)
print("x_alpha: ", x_alpha)
# Out:
# Dn:  0.2570685083085483
# x_alpha:  0.19407039031413997

# %% [markdown]
# $Dn > x_\alpha \Rightarrow$ основная гипотеза отвергается

# %%
plt.title('Функции выборочной функции распределения ошибки и нормального распределения')
plt.xlabel('x') 
plt.ylabel('Значения функций')
plt.plot(v, F, color='red')
plt.plot(v, Fn, color='blue')
plt.show()
plt.show()

# %% [markdown]
# #### 7) В предположении нормальности ошибок построить доверительные интервалы для параметров $\beta_0$, $\beta_1$, $\beta_2$  уровня доверия 1 − $\alpha$. Написать уравнение доверительного эллипсоида уровня доверия 1 − $\alpha$.
# ДНО функция: $\psi = C^T \beta $
#
# Элемент дисперсии оценки: $ b_\psi = C^T (XX^T)^{-1}C$, где  $C$ - матрица для опеределения параметров, которые будут оценены.
#
# Тогда для построения доверительного интервала: $ \cfrac{\widehat \psi - \psi}{s\sqrt{b}} \sim S_{n-r} $
#
# Доверительный интервал уровня доверия $1 - \alpha$:
#
# $ P_\theta(-x_\alpha \le \cfrac{\widehat \psi - \psi}{s\sqrt{b}} \le x_\alpha) = 1 -\alpha $, <br>
# где квантиль $ x_\alpha : S_{n-r}(x_\alpha) = 1 -\frac{\alpha}{2} $
#
# $b_{\psi_0} = C_0^T (X X^T)^{-1} C_0 = 0.086$
#
#
# $b_{\psi_1} = C_1^T (X X^T)^{-1} C_1 = 0.203$
#
# $b_{\psi_2} = C_2^T (X X^T)^{-1} C_2 = 0.02$
#
# Найдем $x_{\alpha} = S^{-1}_{n - 3}(1 - \frac{\alpha}{2}) = 2.408$

# %%
x_alpha = stats.t.ppf(1-alpha/2, n-3)
print("x_alpha: ", round(x_alpha, 3))
b_0 = np.dot(np.dot(np.array([1, 0, 0]).T, np.linalg.inv(XXT)),np.array([1, 0, 0]))
print("b0:", round(b_0, 3))
b_1 = np.dot(np.dot(np.array([0, 1, 0]).T,np.linalg.inv(XXT)), np.array([0, 1, 0]))
print("b1: ", round(b_1, 3))
b_2 = np.dot(np.dot(np.array([0, 0, 1]).T,np.linalg.inv(XXT)), np.array([0, 0, 1]))
print("b2: ", round(b_2, 3))
print(f'Доверительный интервал [{round(beta[0] - x_alpha * np.sqrt(s) * np.sqrt(b_0), 3)}, {round(beta[0] + x_alpha * np.sqrt(s) * np.sqrt(b_0), 3)}] для beta_0')
print(f'Доверительный интервал [{round(beta[1] - x_alpha * np.sqrt(s) * np.sqrt(b_1), 3)}, {round(beta[1] + x_alpha * np.sqrt(s) * np.sqrt(b_1), 3)}] для beta_1')
print(f'Доверительный интервал [{round(beta[2] - x_alpha * np.sqrt(s) * np.sqrt(b_2), 3)}, {round(beta[2] + x_alpha * np.sqrt(s) * np.sqrt(b_2), 3)}] для beta_2')
# Out:
# x_alpha:  2.408
# b0: 0.086
# b1:  0.203
# b2:  0.02
# Доверительный интервал [7.697, 8.722] для beta_0
# Доверительный интервал [-0.833, 0.743] для beta_1
# Доверительный интервал [-0.31, 0.185] для beta_2

# %% [markdown]
# Доверительный эллипсоид уровня доверия 1 - $\alpha$ :
#
# $ A_\alpha = \{x: (x - \widehat \psi)^T (C^T (XX^T)^{-1}C)^{-1}(x - \widehat \psi) \le qs^2x_\alpha\}$, где $ x_\alpha = F_{q, n-r}(x_\alpha) = 1 - \alpha$
#
# $C = \begin{pmatrix}
#     1 & 0 & 0\\
#     0 & 1 & 0\\
#     0 & 0 & 1
# \end{pmatrix} $
#
# В качестве вектора возьмем $ \vec{x}= P(\hat{\psi} - \psi) $, где P - матрица собственных векторов
#
# Уравнение элипсойда
#
# $(\widehat \psi -  \psi)^T (C^T (XX^T)^{-1}C)^{-1}(\widehat \psi -  \psi) = \lambda_1 x^2 + \lambda_2 y^2 + \lambda_3 z^2 \le qs^2x_\alpha$, где $\lambda_1$ и $\lambda_2$ $\lambda_3$- собственные числа матрицы $XX^T$
#
# $\cfrac{\lambda_1}{qs^2x_\alpha}x^2 + \cfrac{\lambda_2}{qs^2x_\alpha}y^2 + \cfrac{\lambda_3}{qs^2x_\alpha}z^2\le 1$
#
# $1185.768 x^2 +  19.682 y^2 +  2.778 z^2\le 1$
#
# Большая и малая полуоси могут быть вычислены как $ \frac{q s^2 x_{\alpha}}{\lambda_1} $ и $ \frac{q s^2 x_{\alpha}}{\lambda_2} $ соответственно.
#
# $ \vec{x}= P(\hat{\psi} - \psi) = \begin{pmatrix} x \\ y \\ z\end{pmatrix} =\begin{pmatrix}
# -0.13523689 & -0.87904031 & 0.45716422\\
# -0.34313982 & -0.39129755 &-0.85389771\\
# -0.92949774 & 0.27234972 & 0.24871587
# \end{pmatrix}
# \cdot \begin{pmatrix}
# 8.20951273 - \beta_0 \\
# -0.04466727 - \beta_1 \\
# -0.06247455 - \beta_2
# \end{pmatrix}$

# %%
evalues, evectors = np.linalg.eig(XXT)
x_alpha = stats.f.ppf(1-alpha, 2, n-3)
print("x_alpha: ", x_alpha)

a = np.sqrt((2 * s * x_alpha) / evalues[0])
b =  np.sqrt((2 * s * x_alpha) / evalues[1])

print("Большая полуось: ", round(a, 3))
print("Малая полуось: ", round(b, 3))

print("beta: ", beta)
print("Собственные вектора:\n ", evectors)
print("Собственные числа:\n ", evalues)

array = []
for v in evalues:
    array.append(v / 3 * s * x_alpha)
print(round(array[0] , 3),"x^2 + ", round(array[1] , 3),"y^2 + ", round(array[2] , 3),"z^2")
# Out:
# x_alpha:  4.256484406756932
# Большая полуось:  0.053
# Малая полуось:  0.414
# beta:  [ 8.20951273 -0.04466727 -0.06247455]
# Собственные вектора:
#   [[-0.13523689 -0.87904031  0.45716422]
#  [-0.34313982 -0.39129755 -0.85389771]
#  [-0.92949774  0.27234972  0.24871587]]
# Собственные числа:
#   [1582.03308119   26.2600262     3.70689262]
# 1185.768 x^2 +  19.682 y^2 +  2.778 z^2

# %% [markdown]
# #### 8) Сформулировать гипотезу линейной регрессинной зависимости переменной Y от переменной X и проверить её значимость на уровне $\alpha$.h.e)
# ДНО - функция:
# $\psi = C^T \beta $
#
#
# Основная гипотеза:
# $ H_0 : \beta_1 = 0$
#
# Y не зависит от X, если $ y_i \approx \beta_0 + \beta_1 x_i = \beta_0 $\
# То есть $ \beta_1 = 0 $
#
# $ C = \left( \begin{array}{c} 0 \\ 0 \\ 1\end{array} \right) \implies \psi = \left( \begin{array}{c} 0 & 0 & 1 \end{array} \right) \left( \begin{array}{c} \beta_0 \\ \beta_1 \end{array} \right) = \beta_1$
#
# $\mathcal{F} = \cfrac{\widehat \psi^T ((C^T (XX^T)^{-1}C)^{-1}) \widehat \psi}{qs^2} \sim F_{q, n-r}$
#
# $\mathcal{F} = \cfrac{{\widehat \beta_2} ^2}{bqs^2} $
#
# $x_\alpha: F_{q, n-r}(x_\alpha) = 1 - \alpha $

# %%
b = np.dot(np.dot( np.array([0, 0, 1]).T, np.linalg.inv(XXT)),  np.array([0, 0, 1]))
print("b: ", round(b, 3))
F = beta[1] ** 2 / (b * 1 * s)
print("F: ", round(F, 3))
print("alpha: ", alpha)
x_alpha = stats.f(1, n - 2).ppf(1 - alpha)
print("x_alpha: ", round(x_alpha, 4))
a_max = 1 - stats.f.cdf(F, 1, n - 2)
print("Максимальный уровень значимости alpha, при котором может быть принята гипотеза:", a_max)
# Out:
# b:  0.02
# F:  0.188
# alpha:  0.02
# x_alpha:  5.7916
# Максимальный уровень значимости alpha, при котором может быть принята гипотеза: 0.6662877970297642

# %% [markdown]
# $\mathcal{F} < x_\alpha$, принимаем $H_0$

# %% [markdown]
# ## Выводы
# В ходе практической работы былы изучены и реализованы методоы МНК, также была сформулирована линейная регрессия для двух и трех параметров. Построена несмещенная оценка дисперсии, гистограмма с занданным шагом. Оценено растояние полученной оценки до класса нормальных распределений по Колмогорову. Построены различные доверительные интерваля с уровнем доверия 1- $\alpha$ и доверительный элипс. Сформулирована гипотеза линейной регрессионной зависимости и проверена на уровне  $\alpha$. Все эти элементы позволяют проводить статистические выводы о параметрах модели и их значимости.
